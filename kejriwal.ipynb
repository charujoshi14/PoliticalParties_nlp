# %%
import re
import pandas as pd
import os
#kejriwal_class=pd.read_csv('E:\Project\kejriwal.csv')
#kejriwal_class
#kejriwal_class2 = kejriwal_class.text.apply(lambda x: re.sub(r'(?:@[\w_]+)','',x))

# %%
kejriwal_class=pd.read_csv('C://Users//Charu Joshi//Desktop//AAP.csv',delimiter=',',header=0,usecols=[4],encoding='ISO-8859-1')
kejriwal_class
kejriwal_class2 = kejriwal_class.text.apply(lambda x: re.sub(r'(?:@[\w_]+)','',x))

# %%
print(kejriwal_class2)
# Out:
# 0       #3Novices : Breaking on Twitter: Won’t fight P...
# 1        Kejriwal also took in modi in varnasi and los...
# 2         Sir Kejriwal capt is escapist he befooled pe...
# 3          BIGBOSS became so unfair!I thought he quit ...
# 4       Funny Reaction on ARVIND KEJRIWAL 'S Phone Cal...
# 5         kejriwal just talks he is not accepting chal...
# 6                                            AAP Kejriwal
# 7        All options are for kejriwal ... .. duffer..a...
# 8        wts.the use of this news you will still prais...
# 9          #भाग_ Kejriwal _भाग pic.twitter.com/D5MkSaTY5F
# 10         #भाग_ Kejriwal _भाग pic.twitter.com/Q2VCtGcj9z
# 11       Mamta, Kejriwal , papu,maya, sab k sab Bharat...
# 12         #भाग_ Kejriwal _भाग pic.twitter.com/UgaZ5GJtKm
# 13      Punjab Elections 2017: Twitter war between Ama...
# 14         #भाग_ Kejriwal _भाग pic.twitter.com/qFl5hoRpcR
# 15      #भाग_ Kejriwal _भागAmrinder is most corrupt pe...
# ...

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Dr. Ashish
# [nltk_data]     Purohit\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('omw')
# Out:
# [nltk_data] Downloading package omw to C:\Users\Dr. Ashish
# [nltk_data]     Purohit\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw is already up-to-date!
# True

# %%
nltk.download('data') # Open Multilingual WordNet
# Out:
# [nltk_data] Error loading data: Package 'data' not found in index
# False

# %%
help(nltk)
# Out:
# Help on package nltk:
#
# NAME
#     nltk
#
# DESCRIPTION
#     The Natural Language Toolkit (NLTK) is an open source Python library
#     for Natural Language Processing.  A free online book is available.
#     (If you use the library for academic research, please cite the book.)
#
#     Steven Bird, Ewan Klein, and Edward Loper (2009).
#     Natural Language Processing with Python.  O'Reilly Media Inc.
#     http://nltk.org/book
#
#     @version: 3.2.2
#
# PACKAGE CONTENTS
#     app (package)
#     book
#     ccg (package)
#     chat (package)
#     chunk (package)
#     classify (package)
#     cluster (package)
#     collections
#     collocations
#     compat
#     corpus (package)
#     data
#     decorators
#     downloader
#     draw (package)
#     featstruct
#     grammar
#     help
#     inference (package)
#     internals
#     jsontags
#     lazyimport
#     metrics (package)
#     misc (package)
#     parse (package)
#     probability
#     sem (package)
# ...

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
words2 = []
for i in kejriwal_class2:
    words=nltk.word_tokenize(i)
    words2.append(words)
    
print(words2)


from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words=set(stopwords.words("english"))
filtered_sentence=([l.lower() for w in words2 for l in w if not l in stop_words])
len(filtered_sentence)
# Out:
# [['#', '3Novices', ':', 'Breaking', 'on', 'Twitter', ':', 'Won’t', 'fight', 'Punjab', 'elections', ',', 'Kejriwal', 'tweets', 'to', 'Amarinder', 'December', '30', ',', '2016', 'at', '05:12AM', '…'], ['Kejriwal', 'also', 'took', 'in', 'modi', 'in', 'varnasi', 'and', 'lost', 'deposit'], ['Sir', 'Kejriwal', 'capt', 'is', 'escapist', 'he', 'befooled', 'people', 'of', 'ASR', 'in', 'last', 'election', '.', 'He', 'will', 'fight', 'from', 'safe', 'seat'], ['BIGBOSS', 'became', 'so', 'unfair', '!', 'I', 'thought', 'he', 'quit', 'the', 'job', 'and', 'kejriwal', 'became', 'new', 'bigboss'], ['Funny', 'Reaction', 'on', 'ARVIND', 'KEJRIWAL', "'S", 'Phone', 'Call', 'http', ':', '//', 'fb.me/14BxahfNR'], ['kejriwal', 'just', 'talks', 'he', 'is', 'not', 'accepting', 'challenge', 'of', 'yogendra', 'yadav', ',', 'captain', 'Amarinder', '#', 'HolloWMaN'], ['AAP', 'Kejriwal'], ['All', 'options', 'are', 'for', 'kejriwal', '...', '..', 'duffer..aaptards', '...'], ['wts.the', 'use', 'of', 'this', 'news', '
# ...

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
againstKJ=['punjab',
'Trust',
'Dismiss',         
'Amarinder',
'Yogendra',
'Yadav'           
'Assam',
'Card',
'Massive',
'Donation',
'Scam',
'shame'
]
forKJ=['fare',
'Sops',
'shergil',
'shergill',
'Favour'
]

# %%
for i in  range(filtered_sentence.count('#')):
    filtered_sentence.remove('#')

# %%
filtered_sentence.count('#')
# Out:
# 0

# %%
dict1 = {}
dict2 = {}
for i in forKJ:
    dict1[i]=filtered_sentence.count(i.lower())
    
for i in againstKJ:
    dict2[i]=filtered_sentence.count(i.lower())

# %%
dict1
# Out:
# {'Favour': 3, 'Sops': 6, 'fare': 6, 'shergil': 0, 'shergill': 38}

# %%
dict2
# Out:
# {'Amarinder': 386,
#  'Card': 40,
#  'Dismiss': 50,
#  'Donation': 178,
#  'Massive': 168,
#  'Scam': 212,
#  'Trust': 85,
#  'YadavAssam': 0,
#  'Yogendra': 67,
#  'punjab': 923,
#  'shame': 39}

# %%
filtered_sentence
# Out:
# ['3novices',
#  ':',
#  'breaking',
#  'twitter',
#  ':',
#  'won’t',
#  'fight',
#  'punjab',
#  'elections',
#  ',',
#  'kejriwal',
#  'tweets',
#  'amarinder',
#  'december',
#  '30',
#  ',',
#  '2016',
#  '05:12am',
#  '…',
#  'kejriwal',
#  'also',
#  'took',
#  'modi',
#  'varnasi',
#  'lost',
#  'deposit',
#  'sir',
#  'kejriwal',
#  'capt',
#  'escapist',
#  'befooled',
#  'people',
#  'asr',
#  'last',
#  'election',
#  '.',
#  'he',
#  'fight',
#  'safe',
#  'seat',
#  'bigboss',
#  'became',
#  'unfair',
#  '!',
#  'i',
#  'thought',
#  'quit',
#  'job',
#  'kejriwal',
#  'became',
#  'new',
#  'bigboss',
#  'funny',
#  'reaction',
#  'arvind',
#  'kejriwal',
#  "'s",
#  'phone',
#  'call',
#  'http',
#  ':',
#  '//',
#  'fb.me/14bxahfnr',
#  'kejriwal',
#  'talks',
#  'accepting',
#  'challenge',
#  'yogendra',
#  'yadav',
#  ',',
#  'captain',
#  'amarinder',
#  'hollowman',
#  'aap',
#  'kejriwal',
#  'all',
#  'options',
#  'kejriwal',
#  '...',
#  '..',
# ...

# %%
forKJ_count =sum(dict1.values())
againstKJ_count=sum(dict2.values())
total_tweets=kejriwal_class.count()
neutral = total_tweets - (forKJ_count+againstKJ_count)

analysis_d = {"pos": forKJ_count, 'neg': againstKJ_count, 'neu': neutral[0]}
#for i in range(0, forKJ_count):
#    analysis_list.append("pos")
#for i in range(0, againstKJ_count):
#    analysis_list.append("neg")
#for i in range(0, neutral[0]):
#    analysis_list.append("neu")
#print(analysis_list)
analysis_d
# Out:
# {'neg': 2148, 'neu': 7099, 'pos': 53}

# %%
from matplotlib import pyplot as plt
from matplotlib import pylab
plt.bar(range(len(analysis_d)), analysis_d.values(), align='center')
plt.xticks(range(len(analysis_d)), analysis_d.keys())

plt.show()

# %%
forKJ_count
# Out:
# 53

# %%
againstKJ_count
# Out:
# 3150

# %%
neutral[0]
# Out:
# 7099
