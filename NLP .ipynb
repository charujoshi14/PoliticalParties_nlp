# %%
import nltk

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
tweet="@narendramodi Pls also suggest @nitin_gadkari & @mlkhattar to complet #DwarkaExpressway which is troubling 90000 families. A decade of wait."
import re
title = re.sub(r'(?:@[\w_]+)','',tweet)
title
# Out:
# ' Pls also suggest  &  to complet #DwarkaExpressway which is troubling 90000 families. A decade of wait.'

# %%
print(word_tokenize(title))
# Out:
# ['Pls', 'also', 'suggest', '&', 'to', 'complet', '#', 'DwarkaExpressway', 'which', 'is', 'troubling', '90000', 'families', '.', 'A', 'decade', 'of', 'wait', '.']

# %%
import re
import pandas as pd
congress_class=pd.read_csv('C:/Users/Charu Joshi/Documents/sp jain/course material/NLP/congress.csv',delimiter=',',header=0,usecols=[4])
congress_class
congress_class2 = congress_class.text.apply(lambda x: re.sub(r'(?:@[\w_]+)','',x))

# %%
congress_class2
# Out:
# 0        u proved all follower of Pappu is a Pappu  me...
# 1         Congress mein hokar bhi yeh baat kehna kafi ...
# 2        but pappu of Congress & AAP of Delhi crying h...
# 3       I plan to support  for Congress in 2018. We ne...
# 4        I am no Congress supporter nor Modi bhakt. Go...
# 5        yeah my ATX follower says that about South Co...
# 6         don't b blind follower of Congress . U r fru...
# 7        , Congress is the root cause and 3rd option i...
# 8         The viewing of this video should be mandator...
# 9        u r a Trump follower ? Then LGBT rights are g...
# 10      Every donation, petition signature, message to...
# 11      Every donation, petition signature, message to...
# 12       That lutyen mole may have been a creation of ...
# 13      Every donation, petition signature, message to...
# 14      Inspite of being a devout follower of Gandhi, ...
# 15      New day, new tweets, new stats. 1 follower , 0...
# ...

# %%
words2 = []
for i in congress_class2:
    words=word_tokenize(i)
    words2.append(words)
    
print(words2)
# Out:
# [['u', 'proved', 'all', 'follower', 'of', 'Pappu', 'is', 'a', 'Pappu', 'meant', '``', 'as', 'nobody', 'is', 'joining', 'Congress', 'social', 'media', 'exec', 'become', 'Spokies', "''", ';', ';', ';', ';', "''", '814506547040559105'], ['Congress', 'mein', 'hokar', 'bhi', 'yeh', 'baat', 'kehna', 'kafi', 'himmat', 'ki', 'baat', 'h.True', 'RaGa', 'follower', '.'], ['but', 'pappu', 'of', 'Congress', '&', 'AAP', 'of', 'Delhi', 'crying', 'he', 'was', 'not', 'a', 'bjp', 'follower', ',', 'so', 'arrested', '.', 'This', 'is', 'modified/RSS', 'stunt', 'say', 'didi', 'd', 'tigress'], ['I', 'plan', 'to', 'support', 'for', 'Congress', 'in', '2018', '.', 'We', 'need', 'to', 'dump', 'Trump', 'follower', 'Darrell', 'Issa', '!', 'https', ':', '//www', '.', 'google.com/amp/www.sandie', 'gouniontribune.com/news/politics/sd-me-applegate-announce-20161129-story', ',', 'amp.html', '…'], ['I', 'am', 'no', 'Congress', 'supporter', 'nor', 'Modi', 'bhakt', '.', 'Go', 'with', 'issues', 'unlike', 'you', 'who', 's
# ...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
stop_words=set(stopwords.words("english"))
filtered_sentence=([l for w in words2 for l in w if not l in stop_words])

# %%
len(filtered_sentence)
filtered_sentence
# Out:
# ['u',
#  'proved',
#  'follower',
#  'Pappu',
#  'Pappu',
#  'meant',
#  '``',
#  'nobody',
#  'joining',
#  'Congress',
#  'social',
#  'media',
#  'exec',
#  'become',
#  'Spokies',
#  "''",
#  ';',
#  ';',
#  ';',
#  ';',
#  "''",
#  '814506547040559105',
#  'Congress',
#  'mein',
#  'hokar',
#  'bhi',
#  'yeh',
#  'baat',
#  'kehna',
#  'kafi',
#  'himmat',
#  'ki',
#  'baat',
#  'h.True',
#  'RaGa',
#  'follower',
#  '.',
#  'pappu',
#  'Congress',
#  '&',
#  'AAP',
#  'Delhi',
#  'crying',
#  'bjp',
#  'follower',
#  ',',
#  'arrested',
#  '.',
#  'This',
#  'modified/RSS',
#  'stunt',
#  'say',
#  'didi',
#  'tigress',
#  'I',
#  'plan',
#  'support',
#  'Congress',
#  '2018',
#  '.',
#  'We',
#  'need',
#  'dump',
#  'Trump',
#  'follower',
#  'Darrell',
#  'Issa',
#  '!',
#  'https',
#  ':',
#  '//www',
#  '.',
#  'google.com/amp/www.sandie',
#  'gouniontribune.com/news/politics/sd-me-applegate-announce-20161129-story',
#  ',',
#  'amp.html',
#  '…',
#  'I',
#  'Congress',
# ...

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  'd',
#  'did',
#  'didn',
#  'do',
#  'does',
#  'doesn',
#  'doing',
#  'don',
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  'has',
#  'hasn',
#  'have',
#  'haven',
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  'more',
#  'most',
#  'mustn',
#  'my',
#  'myself',
#  'needn',
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
# ...

# %%
type(words)
# Out:
# list

# %%
print(words2)
# Out:
# [['u', 'proved', 'all', 'follower', 'of', 'Pappu', 'is', 'a', 'Pappu', 'meant', '``', 'as', 'nobody', 'is', 'joining', 'Congress', 'social', 'media', 'exec', 'become', 'Spokies', "''", ';', ';', ';', ';', "''", '814506547040559105'], ['Congress', 'mein', 'hokar', 'bhi', 'yeh', 'baat', 'kehna', 'kafi', 'himmat', 'ki', 'baat', 'h.True', 'RaGa', 'follower', '.'], ['but', 'pappu', 'of', 'Congress', '&', 'AAP', 'of', 'Delhi', 'crying', 'he', 'was', 'not', 'a', 'bjp', 'follower', ',', 'so', 'arrested', '.', 'This', 'is', 'modified/RSS', 'stunt', 'say', 'didi', 'd', 'tigress'], ['I', 'plan', 'to', 'support', 'for', 'Congress', 'in', '2018', '.', 'We', 'need', 'to', 'dump', 'Trump', 'follower', 'Darrell', 'Issa', '!', 'https', ':', '//www', '.', 'google.com/amp/www.sandie', 'gouniontribune.com/news/politics/sd-me-applegate-announce-20161129-story', ',', 'amp.html', '…'], ['I', 'am', 'no', 'Congress', 'supporter', 'nor', 'Modi', 'bhakt', '.', 'Go', 'with', 'issues', 'unlike', 'you', 'who', 's
# ...
